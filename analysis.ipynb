# %%
from src.stats_utils import fit_retention_curve
from src.visual_utils import show_retention_curve

# %%
days = [1, 3, 7, 14]
retention_A = [0.53, 0.27, 0.17, 0.06]
retention_B = [0.48, 0.25, 0.19, 0.09]

# %%
parameters = fit_retention_curve(days, retention_A)
show_retention_curve(days, retention_A, parameters)
